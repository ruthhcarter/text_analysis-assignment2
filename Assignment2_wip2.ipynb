# %% [markdown]
# # PSY 341K Text Analysis for Behavioral Data Science
# ##### Spring 2024; written by: Prof Desmond Ong (desmond.ong@utexas.edu)
#
# ## Assignment 2
#
# In this assignment we'll be processing a dataset using an NLP pipeline to extract linguistic features (n-grams), and then using these features to predict an outcome of interest.
#
# In Assignment 1, we walked you through each step of the 'research' process. In Assignment 2, we'll guide you through the high-level goals, but you'll have a bit more latitude to decide how to go about each step in the process. (You have all the "mechanics" in terms of the code required, from the Tutorials). This assignment will be more challenging because it is a bit more open-ended, and the idea is to gradually build you towards executing your research project, which is the other extreme where you decide everything (and it does get pretty overwhelming!).

# %%
import nltk
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /Users/ruthcarter/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
import numpy as np
from nltk.corpus import twitter_samples
import pandas as pd

# %% [markdown]
# The data we are using is a small sample of tweets that is packaged into `nltk.corpus`, and they are labelled as either "positive" or "negative".
#
#
# ### Your goal in this Assignment is to investigate what linguistic features predict a tweet being "Positive" or "Negative".
#
# In other words, you will calculate some linguistic features of interest, e.g., unigrams, bigrams, if you like, trigrams. You may also calculate other features, e.g., word count.
#
# You will then use those features in a logistic regression (or other classification technique of your choosing) to predict the label of the tweets.

# %% [markdown]
# ### Reading in the data

# %% [markdown]
# The data consists of 5,000 positive and 5,000 negative tweets.

# %%
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')

print(len(positive_tweets), len(negative_tweets))

all_tweets = positive_tweets + negative_tweets
# Out:
# 5000 5000

# %%
# print out the first ten positive tweets, and the first ten negative tweets, to get a sense of the text.

# --- your code ---
print(positive_tweets[:10])

print(negative_tweets[:10])
# Out:
# ['#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)', '@Lamb2ja Hey James! How odd :/ Please call our Contact Centre on 02392441234 and we will be able to assist you :) Many thanks!', '@DespiteOfficial we had a listen last night :) As You Bleed is an amazing track. When are you in Scotland?!', '@97sides CONGRATS :)', 'yeaaaah yippppy!!!  my accnt verified rqst has succeed got a blue tick mark on my fb profile :) in 15 days', '@BhaktisBanter @PallaviRuhail This one is irresistible :)\n#FlipkartFashionFriday http://t.co/EbZ0L2VENM', "We don't like to keep our lovely customers waiting for long! We hope you enjoy! Happy Friday! - LWWF :) https://t.co/smyYriipxI", '@Impatientraider On second thought, there’s just not enough time for a DD :) But new shorts entering system. Sheep must be buying.', 'Jgh , but we have to go to Bayan :D bye', 'As an act of mischievousness, am calling the ETL layer of our in-house warehousing app Katamari.\n\nWell… as the name implies :p.']
# ['hopeless for tmr :(', "Everything in the kids section of IKEA is so cute. Shame I'm nearly 19 in 2 months :(", '@Hegelbon That heart sliding into the waste basket. :(', '“@ketchBurning: I hate Japanese call him "bani" :( :(”\n\nMe too', 'Dang starting next week I have "work" :(', "oh god, my babies' faces :( https://t.co/9fcwGvaki0", '@RileyMcDonough make me smile :((', '@f0ggstar @stuartthull work neighbour on motors. Asked why and he said hates the updates on search :( http://t.co/XvmTUikWln', 'why?:("@tahuodyy: sialan:( https://t.co/Hv1i0xcrL2"', 'Athabasca glacier was there in #1948 :-( #athabasca #glacier #jasper #jaspernationalpark #alberta #explorealberta #… http://t.co/dZZdqmf7Cz']

# %% [markdown]
# #### Comment on your observations! What do you notice? Are there things that you have to take note of?
#
# #### Your Written Answer here
# - The positive tweets use a lot of smiley faces and exclamation marks. They also seem to interact with other users more often. There are also abbreviations of words (like tmr for tomorrow or fb for facebook, or ETL for... something...) that we need to consider. Otherwise, we won't fully understand the meaning of the tweet. Also, since hashtags are usually one whole word, it will be difficult to analyze (like #FlipkartFashionFriday). Also, not many tweets in this dataset seem to use emojis, but it looks like it does occasionally happen. I think this means we should use the "from nltk.tokenize.casual import TweetTokenizer" instead of normally tokenizing the text. Additionally, since tweets are popular in many countries, we may need to account for different spellings of English words (like neighbour and neighbor).

# %% [markdown]
# ### Calculating Features
#
# Let's process the tweets! In class, we've covered a number of different preprocessing steps to calculate linguistic features. The choice of which steps to use (or not use) really depends on the specific context.
#
# - For example, we talked about why stop words are removed, but also why it may be interesting to keep stop words.
#     -
# - As another example, we talked about identifing Named Entities. But what do you do with them? You could decide to keep them in as features if you have specific hypotheses (e.g., if you're studying some political text, it might be handy to keep in the names of certain politicians). Or you might decide that actually names are irrelevant to your research question and remove them.
#     - might not be relevant, since we're just looking at whether tweets are positive or negative. there's not really any specific entities that would aid in whether tweets are pos or neg.
#
# The key is to really take some time to understand your data, and especially as it pertains to your hypotheses. As in Assignment 1, please `print()` and read some of the examples to get a sense for the language used. Please also `print()` out your variables as you are calculating them. Then you might notice additional issues that you may need to correct.
#
# - A simple one that we didn't cover in class (because it's quite straightforward) is lower-case normalization: that is, converting all the text to lowercase, say using `.lower()`. This is so `A strawberry` and `a strawberry` will become the same bigram. BUT lower-casing will also make `American` into `american`. (Also, lower-casing will throw off the POS-taggers/NER identifiers, which are case sensitive).

# %% [markdown]
# #### Note: Creating a feature array
#
# Note that after you preprocess and calculate your unigrams/n-grams, you need to convert the features into a large word-count array, with a corresponding "vocabulary".
#
# For example, we can take all the unigrams and arrange them alphabetically:
#
# - ["American", "and", ...]
#
# and if the first tweet is "this American is a proud American" (so 2 `American`s and 0 `and`s), and the second tweet is "and I am happy" (0 `American` and 1 `and`), then we need to create a feature array that looks like:
#
# - [[2, 0, ...]
# - [0, 1, ...]
# - ... ]
#
# such that the rows give the features for each tweet, while the columns give the word-count of each n-gram in the vocabulary. This `num_tweet` by `num_feature` array can then be used as the independent variables ("X") in the regression.

# %% [markdown]
# ## Please process the text and calculate unigram and bigram features for each tweet.
#
# Please add as many code boxes as you need, and document your steps (e.g., with markdown chunks or with in-line comments).

# %%
#### Your code below

# %%
#tokenize the tweets: 
from nltk.tokenize.casual import TweetTokenizer
ttokenizer = TweetTokenizer() # here we have to create a TweetTokenizer object

positive_tweets_list = [] 
negative_tweets_list = [] 


#tokenizing pos tweets
for i in positive_tweets: 
    j= i.lower()
    tokenized = ttokenizer.tokenize(j)
    positive_tweets_list.append(tokenized)
    
print(positive_tweets_list[0:5])



#tokenizing neg tweets
for i in negative_tweets: 
    j= i.lower()
    tokenized = ttokenizer.tokenize(j)
    negative_tweets_list.append(tokenized)
    
print(negative_tweets_list[0:5])
# Out:
# [['#followfriday', '@france_inte', '@pkuchly57', '@milipol_paris', 'for', 'being', 'top', 'engaged', 'members', 'in', 'my', 'community', 'this', 'week', ':)'], ['@lamb2ja', 'hey', 'james', '!', 'how', 'odd', ':/', 'please', 'call', 'our', 'contact', 'centre', 'on', '02392441234', 'and', 'we', 'will', 'be', 'able', 'to', 'assist', 'you', ':)', 'many', 'thanks', '!'], ['@despiteofficial', 'we', 'had', 'a', 'listen', 'last', 'night', ':)', 'as', 'you', 'bleed', 'is', 'an', 'amazing', 'track', '.', 'when', 'are', 'you', 'in', 'scotland', '?', '!'], ['@97sides', 'congrats', ':)'], ['yeaaaah', 'yippppy', '!', '!', '!', 'my', 'accnt', 'verified', 'rqst', 'has', 'succeed', 'got', 'a', 'blue', 'tick', 'mark', 'on', 'my', 'fb', 'profile', ':)', 'in', '15', 'days']]
# [['hopeless', 'for', 'tmr', ':('], ['everything', 'in', 'the', 'kids', 'section', 'of', 'ikea', 'is', 'so', 'cute', '.', 'shame', "i'm", 'nearly', '19', 'in', '2', 'months', ':('], ['@hegelbon', 'that', 'heart', 'sliding', 'into', 'the', 'waste', 'basket', '.', ':('], ['“', '@ketchburning', ':', 'i', 'hate', 'japanese', 'call', 'him', '"', 'bani', '"', ':(', ':(', '”', 'me', 'too'], ['dang', 'starting', 'next', 'week', 'i', 'have', '"', 'work', '"', ':(']]

# %%
#calculating unigram features 


#unigram feat for pos tweets: 
unigram_pos_freq = []

for i in positive_tweets_list: 
    unigram_frequency_distribution = nltk.FreqDist(i)
    unigram_pos_freq.append(unigram_frequency_distribution)

unigram_pos = [tuple(entry.items()) for entry in unigram_pos_freq]

#unigram feat for neg tweets: 
unigram_neg_freq = []

for i in negative_tweets_list: 
    unigram_frequency_distribution = nltk.FreqDist(i)
    unigram_neg_freq.append(unigram_frequency_distribution)

unigram_neg = [tuple(entry.items()) for entry in unigram_neg_freq]


all_unigrams = unigram_pos + unigram_neg

all_tweets = positive_tweets_list + negative_tweets_list

# %%
len(all_unigrams)
# Out:
# 10000

# %%
#calculating unigram feature array: 

flattened_list = [item for sublist in all_unigrams for item in sublist]

unigrams_df = pd.DataFrame(flattened_list)

unique_unigrams = pd.Series(unigrams_df[0].sort_values().unique())
# Out:
# 0                       !
# 1                       "
# 2                       #
# 3                 ##bbmme
# 4        ##segalakatakata
#                ...
# 21732                   🚮
# 21733                   🚲
# 21734                   󾆖
# 21735                   󾌴
# 21736                   󾰀
# Length: 21737, dtype: object

# %%
import re
from collections import Counter

# %%
word_counts = Counter()
unigram_list = []

for tweet_tokens in all_tweets:
    # Iterate over each word in the array of words to check
    for word in unique_unigrams:
        # Count the occurrences of the word in the tweet tokens and update the Counter
        word_counts[word] += tweet_tokens.count(word)

# %%
unigram_counts_per_tweet = []

# Iterate over each tweet
for tweet in all_tweets:
    # Initialize a Counter for the current tweet
    word_counts = Counter()
    
    # Iterate over each unique unigram
    for word in unique_unigrams:
        # Count the occurrences of the word in the tweet tokens and update the Counter
        word_counts[word] = tweet_tokens.count(word)
    
    # Append the Counter to the list
    unigram_counts_per_tweet.append(word_counts)
    
values_list = [count for counter in unigram_counts_per_tweet for count in counter.values()]

# %%
unigram_counts_per_tweet[0]
# Out:
# Counter({'!': 0,
#          '"': 0,
#          '#': 0,
#          '##bbmme': 0,
#          '##segalakatakata': 0,
#          '#100reasonstovisitmombasa': 0,
#          '#1948': 0,
#          '#1tbps4': 0,
#          '#2fm': 0,
#          '#39': 0,
#          '#4thstreetmusic': 0,
#          '#50notifications': 0,
#          '#5minute': 0,
#          '#actuallythough': 0,
#          '#addme': 0,
#          '#addmeonbbm': 0,
#          '#addmeonsnapchat': 0,
#          '#admin_myung': 0,
#          '#aflblueshawks': 0,
#          '#agnezmo': 0,
#          '#airfields': 0,
#          '#airforce': 0,
#          '#airport': 0,
#          '#akshaymostlovedsuperstarever': 0,
#          '#akua': 0,
#          '#al_master_band': 0,
#          '#alberta': 0,
#          '#aldub': 0,
#          '#alevel': 0,
#          '#alienthought': 0,
#          '#allgoodthingske': 0,
#          '#aluminiumfree': 0,
#          '#alwayskeepfighting': 0,
#          '#am': 0,
#          '#amateur': 0,
#          '#amazon': 0,
#          '#aminormalyet': 0,
#          '#amnotness': 0,
#          '#android': 0,
#          '#angel': 0,
#          '#ans2win': 0,
#          '#anushka': 0,
#          '#anywayhedidanicejob': 0,
#          '#aragalang08': 0,
#          '#art': 0,
#          '#ashramcalling': 0,
#          '#askaman': 0,
#          '#askfinnick': 0,
#          '#askurban': 0,
#          '#athabasca': 0,
#          '#atk': 0,
#          '#ausfailia': 0,
#          '#autofollow': 0,
#          '#auvssscr': 0,
#          '#awami': 0,
#          '#babe': 0,
#          '#backflip': 0,
#          '#bad': 0,
#          '#bad4thwin': 0,
#          '#bae': 0,
#          '#bajrangibhaijaanhighestweek1': 0,
#          '#bajrangibhaijaanstorm': 0,
#          '#band': 0,
#          '#banter': 0,
#          '#barkada': 0,
#          '#barsostay': 0,
#          '#basketball': 0,
#          '#batalladelosgallos': 0,
#          '#batb': 0,
#          '#battlefield': 0,
#          '#bb17': 0,
#          '#bblf': 0,
#          '#bbloggers': 0,
#          '#bbmadeinmanila': 0,
#          '#bbmme': 0,
#          '#bbmpin': 0,
#          '#bboying': 0,
#          '#bc': 0,
#          '#bcyc': 0,
#          '#be': 0,
#          '#beauty': 0,
#          '#bebravetoday': 0,
#          '#beliebers': 0,
#          '#bellevue': 0,
#          '#bellybutton': 0,
#          '#bellybuttons': 0,
#          '#beme': 0,
#          '#bemeapp': 0,
#          '#bemecode': 0,
#          '#beograd': 0,
#          '#beonknockknock': 0,
#          '#besteverdoctorwhoepisode': 0,
#          '#bestfriend': 0,
#          '#bestoftheday': 0,
#          '#bestweekend': 0,
#          '#betting': 0,
#          '#bff': 0,
#          '#bffs': 0,
#          '#bindingofissac': 0,
#          '#birmingham': 0,
#          '#birthday': 0,
#          '#birthdaygirl': 0,
#          '#birthdaymoneyforjesusjuice': 0,
#          '#birthdaymonth': 0,
#          '#birthdaypresent': 0,
#          '#blackcountryfair': 0,
#          '#blacklivesmatter': 0,
#          '#blamehoney': 0,
#          '#blameshoghicp': 0,
#          '#bleedgreen': 0,
#          '#blockjam': 0,
#          '#blog': 0,
#          '#bloggersrequired': 0,
#          '#bloggerswanted': 0,
#          '#blonde': 0,
#          '#bloodline': 0,
#          '#blowjob': 0,
#          '#bluejays': 0,
#          '#bluesidemenxix': 0,
#          '#bmc': 0,
#          '#bollywood': 0,
#          '#bombing': 0,
#          '#bookreview': 0,
#          '#boom': 0,
#          '#booty': 0,
#          '#borderlands': 0,
#          '#bored': 0,
#          '#bot': 0,
#          '#bowwowchicawowwow': 0,
#          '#boxroomcrafts': 0,
#          '#brainchild': 0,
#          '#braindots': 0,
#          '#branding': 0,
#          '#brasileirao': 0,
#          '#breaktym': 0,
#          '#breconbeacons': 0,
#          '#brewproject': 0,
#          '#brijresidency': 0,
#          '#brilliant': 0,
#          '#bringmethehorizon': 0,
#          '#bristolart': 0,
#          '#brum': 0,
#          '#buckinghampalace': 0,
#          '#budapestgp': 0,
#          '#buddy': 0,
#          '#bugbounty': 0,
#          '#bulldog': 0,
#          '#bunso': 0,
#          '#burger': 0,
#          '#burgers': 0,
#          '#burnley': 0,
#          '#buynotanapologyonitunes': 0,
#          '#caesarspalace': 0,
#          '#cajunchicken': 0,
#          '#cakehamper': 0,
#          '#calibraksaep': 0,
#          '#calibraskaep': 0,
#          '#callinganimalabusehotlineasap': 0,
#          '#cam4': 0,
#          '#cambridge': 0,
#          '#camsex': 0,
#          '#canvas': 0,
#          '#cardgame': 0,
#          '#cc': 0,
#          '#centrifugal': 0,
#          '#ceo1month': 0,
#          '#chaloniklo': 0,
#          '#chat': 0,
#          '#cheatday': 0,
#          '#checking': 0,
#          '#cheesydelights': 0,
#          '#cheltenham': 0,
#          '#cheshire': 0,
#          '#chocolate': 0,
#          '#choiceinternationalartist': 0,
#          '#cimbom': 0,
#          '#circuscircus': 0,
#          '#cjradacomateada': 0,
#          '#clapham': 0,
#          '#classicassures': 0,
#          '#clientvisit': 0,
#          '#climatechange': 0,
#          '#cnn': 0,
#          '#cocktails': 0,
#          '#coffee': 0,
#          '#colorpencils': 0,
#          '#colors': 0,
#          '#commercial': 0,
#          '#commodore64': 0,
#          '#community': 0,
#          '#concert': 0,
#          '#contestkiduniya': 0,
#          '#coolingtowers': 0,
#          '#cosplay': 0,
#          '#cosplayprogress': 0,
#          '#costacc': 0,
#          '#countrymusic': 0,
#          '#countthecost': 0,
#          '#couple': 0,
#          '#couscous': 0,
#          '#cp': 0,
#          '#cplt20': 0,
#          '#cray': 0,
#          '#credits': 0,
#          '#cretaperfect4me': 0,
#          '#cretaperfectsuv': 0,
#          '#crowdfunding': 0,
#          '#crush': 0,
#          '#csrracing': 0,
#          '#cumbria': 0,
#          '#cumshot': 0,
#          '#cute': 0,
#          '#cyclerevolution': 0,
#          '#cycling': 0,
#          '#cyprus': 0,
#          '#dancetastic': 0,
#          '#danzell': 0,
#          '#day2': 0,
#          '#dayofarch': 0,
#          '#dealsuthaonotebachao': 0,
#          '#dearslim': 0,
#          '#deathbybaconsmell': 0,
#          '#deathcure': 0,
#          '#deathofgrass': 0,
#          '#decorating': 0,
#          '#dedicatedfan': 0,
#          '#delivery': 0,
#          '#dessert': 0,
#          '#determination': 0,
#          '#development': 0,
#          '#digitalexeter': 0,
#          '#digitalmarketing': 0,
#          '#dinner': 0,
#          '#dirtykik': 0,
#          '#disappointed': 0,
#          '#discrimination': 0,
#          '#dishoom': 0,
#          '#disneyinfinity': 0,
#          '#divinediscontent': 0,
#          '#diyflowers': 0,
#          '#djderek': 0,
#          '#djset': 0,
#          '#djstruthmate': 0,
#          '#dmme': 0,
#          '#docopenhagen': 0,
#          '#domesticviolence': 0,
#          '#dominion': 0,
#          '#doodle': 0,
#          '#dota2': 0,
#          '#dreamteam': 0,
#          '#drinkitallup': 0,
#          '#dtangle': 0,
#          '#dublin': 0,
#          '#dukefreebiefriday': 0,
#          '#eatmeat': 0,
#          '#ebony': 0,
#          '#eczema': 0,
#          '#edm': 0,
#          '#educampakl': 0,
#          '#eh': 0,
#          '#eid': 0,
#          '#eidwithgrofers': 0,
#          '#ejayster': 0,
#          '#eksperimencinta': 0,
#          '#elephantgod': 0,
#          '#elfindelmundo': 0,
#          '#elgin': 0,
#          '#elizabetholsen': 0,
#          '#emojasp_here': 0,
#          '#england': 0,
#          '#enjoy': 0,
#          '#entrepreneur': 0,
#          '#equalityact': 0,
#          '#escape': 0,
#          '#essay': 0,
#          '#estatic': 0,
#          '#etid': 0,
#          '#etsy': 0,
#          '#excited': 0,
#          '#exo': 0,
#          '#expediajobs': 0,
#          '#explorealberta': 0,
#          '#extremesports': 0,
#          '#fabfriday': 0,
#          '#facetime': 0,
#          '#fahrinahmad': 0,
#          '#fail2ban': 0,
#          '#failsatlife': 0,
#          '#fallout4': 0,
#          '#family': 0,
#          '#familyhome': 0,
#          '#fanart': 0,
#          '#fantastic': 0,
#          '#farm': 0,
#          '#fashionfriday': 0,
#          '#favourites': 0,
#          '#fb': 0,
#          '#feelgoodfriday': 0,
#          '#feelinggood': 0,
#          '#feelslikeanidiot': 0,
#          '#feminism': 0,
#          '#fenestoscope': 0,
#          '#fever': 0,
#          '#ff': 0,
#          '#ffback': 0,
#          '#fightingmcirene': 0,
#          '#fightstickfriday': 0,
#          '#filbarbarian': 0,
#          '#finance': 0,
#          '#findavip': 0,
#          '#finddjderek': 0,
#          '#findyourfit': 0,
#          '#fingerscrossed': 0,
#          '#finland': 0,
#          '#first50europe': 0,
#          '#fish': 0,
#          '#fitfa': 0,
#          '#fixedgearfrenzy': 0,
#          '#flipkartfashionfriday': 0,
#          '#flippin': 0,
#          '#flockstars': 0,
#          '#flowers': 0,
#          '#fls': 0,
#          '#flyhigh': 0,
#          '#fm15': 0,
#          '#fmfamily': 0,
#          '#fnaf4': 0,
#          '#foampit': 0,
#          '#foiegras': 0,
#          '#follow': 0,
#          '#followback': 0,
#          '#followfriday': 0,
#          '#followmeaaron': 0,
#          '#food': 0,
#          '#foodforthought': 0,
#          '#foodiefridays': 0,
#          '#foreveralone': 0,
#          '#forklift': 0,
#          '#fortune500': 0,
#          '#free': 0,
#          '#freebiefriday': 0,
#          '#freedom': 0,
#          '#french': 0,
#          '#frequentflyer': 0,
#          '#fresherstofinals': 0,
#          '#friday': 0,
#          "#friday's": 0,
#          '#fridaydownpour': 0,
#          '#fridayfauxpas': 0,
#          '#fridayfeeling': 0,
#          '#fridayfreebie': 0,
#          '#fridayfun': 0,
#          '#fridayfunday': 0,
#          '#fridaylouge': 0,
#          '#fridays': 0,
#          '#friends': 0,
#          '#friskyfiday': 0,
#          '#friskyfriday': 0,
#          '#friyay': 0,
#          '#frnds': 0,
#          '#frustration': 0,
#          '#fuck': 0,
#          '#fun': 0,
#          '#funny': 0,
#          '#futurereleases': 0,
#          '#fxhelp': 0,
#          '#fyeah': 0,
#          '#gamedesign': 0,
#          '#gamedev': 0,
#          '#gamer': 0,
#          '#gamers': 0,
#          '#ganesha': 0,
#          '#gay': 0,
#          '#geek': 0,
#          '#ges2015kenya': 0,
#          '#geskenya': 0,
#          '#getthescoop': 0,
#          '#getwellsoonamber': 0,
#          '#giachietittiwedding': 0,
#          '#girl': 0,
#          '#girlfriendsmya': 0,
#          '#girls': 0,
#          '#giveaway': 0,
#          '#givecodpieceachance': 0,
#          '#giveitup': 0,
#          '#glacier': 0,
#          '#goa': 0,
#          '#gobigorgohome': 0,
#          '#godonna': 0,
#          '#gohf': 0,
#          '#gohf2015': 0,
#          '#goldbugs': 0,
#          '#goldcoast': 0,
#          '#goodafternoon': 0,
#          '#goodmorning': 0,
#          '#goodmusic': 0,
#          '#goodnight': 0,
#          '#goodwynsgoodies': 0,
#          '#goodyear': 0,
#          '#goofingaround': 0,
#          '#gorgeous': 0,
#          '#got7': 0,
#          '#gotham': 0,
#          '#gottolovebanks': 0,
#          '#gp': 0,
#          '#graphicdesign': 0,
#          '#greatkenya': 0,
#          '#greece': 0,
#          '#greekcrisis': 0,
#          '#greeks': 0,
#          '#greysonchance': 0,
#          '#gross': 0,
#          '#growinguppoor': 0,
#          '#gto': 0,
#          '#gunashekar': 0,
#          '#guncontrol': 0,
#          '#gutted': 0,
#          '#gym': 0,
#          '#h_my_king': 0,
#          '#haaretz': 0,
#          '#hagergang': 0,
#          '#haileyhelps': 0,
#          '#hair': 0,
#          '#hale': 0,
#          '#halesowen': 0,
#          '#hannibal': 0,
#          '#happy': 0,
#          '#happyalien': 0,
#          '#happybirthdayemilybett': 0,
#          '#happycustomers': 0,
#          '#happyfriday': 0,
#          '#happyfriedday': 0,
#          '#happyweekend': 0,
#          '#hashtags': 0,
#          '#haveagoodday': 0,
#          '#hbdme': 0,
#          '#healthylifestyle': 0,
#          '#hello': 0,
#          '#helsinki': 0,
#          '#henessydiaries': 0,
#          '#heroes': 0,
#          '#hibye': 0,
#          '#highschooldays': 0,
#          '#hindugod': 0,
#          '#hinduism': 0,
#          '#hiring': 0,
#          '#holiday': 0,
#          '#hopetowin': 0,
#          '#horny': 0,
#          '#hornykik': 0,
#          '#horseracing': 0,
#          '#horseracingtips': 0,
#          '#horses': 0,
#          '#hot': 0,
#          '#hotairballoon': 0,
#          '#hotel': 0,
#          '#hotels': 0,
#          '#hotfmnoaidilforariana': 0,
#          '#hotgirls': 0,
#          '#hotmusicdelocos': 0,
#          '#hotnsexy': 0,
#          '#hotscratch': 0,
#          '#hotspotwithdanris': 0,
#          '#hottie': 0,
#          '#housemusic': 0,
#          '#hr': 0,
#          '#hrdstellobama': 0,
#          '#hugs': 0,
#          '#hulkhogan': 0,
#          '#hushedcallwithfraydoe': 0,
#          '#hushedpinwithsammy': 0,
#          '#huskies': 0,
#          '#hype': 0,
#          '#hypixel': 0,
#          '#hyungbot': 0,
#          '#iamamonster': 0,
#          '#iamca': 0,
#          '#icecream': 0,
#          '#icecreammaster': 0,
#          '#ifimeetanalien': 0,
#          '#igersoftheday': 0,
#          '#ihatesomepeople': 0,
#          '#ikprideofpak': 0,
#          '#ilikeit': 0,
#          '#iloveyou': 0,
#          '#imintoher': 0,
#          '#imveryverysorry': 0,
#          '#incall': 0,
#          '#incredibleindia': 0,
#          '#indian': 0,
#          '#indiedev': 0,
#          '#indiemusic': 0,
#          '#indonesia': 0,
#          '#ineedfeminismbecause': 0,
#          '#innie': 0,
#          '#innovation': 0,
#          '#inspire': 0,
#          '#inspy': 0,
#          '#instagood': 0,
#          '#instagram': 0,
#          '#instamood': 0,
#          '#intel': 0,
#          '#interracial': 0,
#          '#ios8': 0,
#          '#iqrar': 0,
#          '#iran': 0,
#          '#irandeal': 0,
#          '#iraq': 0,
#          '#isibaya': 0,
#          '#isis': 0,
#          '#isolated': 0,
#          '#israel': 0,
#          '#itsamarvelthing': 0,
#          '#itter': 0,
#          '#iwishiknewbetter': 0,
#          '#jabongatpumaurbanstampede': 0,
#          '#jaredpadalecki': 0,
#          '#jasper': 0,
#          '#jaspernationalpark': 0,
#          '#jcreport': 0,
#          '#jealous': 0,
#          '#jebbush': 0,
#          '#jedzjabłka': 0,
#          '#jeep': 0,
#          '#jensenackles': 0,
#          '#jeremy4leader': 0,
#          '#jets': 0,
#          '#jezwecan': 0,
#          '#jgh': 0,
#          '#jilla': 0,
#          '#jiva': 0,
#          '#job': 0,
#          '#jobs': 0,
#          '#johnforceo': 0,
#          '#johnyherbert': 0,
#          '#jonathancreek': 0,
#          '#jordan': 0,
#          '#journeyps4': 0,
#          '#journorequest': 0,
#          '#judo': 0,
#          '#july24th': 0,
#          '#jumma_mubarik': 0,
#          '#jummamubarak': 0,
#          '#jummaprayer': 0,
#          '#jumpgiants': 0,
#          '#justgotkanekified': 0,
#          '#justiceforsandrabland': 0,
#          '#kadhafi': 0,
#          '#kapatidkongpogi': 0,
#          '#karani': 0,
#          '#karibumombasa': 0,
#          '#kca': 0,
#          '#keepitlocal': 0,
#          '#keepsafealways': 0,
#          '#kfc': 0,
#          '#kfckitchentours': 0,
#          '#kianweareproud': 0,
#          '#kidschoiceawards2015': 0,
#          '#kik': 0,
#          '#kikchat': 0,
#          '#kikgirl': 0,
#          '#kikhorny': 0,
#          '#kikkomansabor': 0,
#          '#kikme': 0,
#          '#kikmeboys': 0,
#          '#kikmeguys': 0,
#          '#kikmenow': 0,
#          '#kikmsn': 0,
#          '#kiksex': 0,
#          '#kiksexting': 0,
#          "#kinara's": 0,
#          '#kissme': 0,
#          '#kitkat': 0,
#          '#kizomba': 0,
#          '#ktksbye': 0,
#          '#ku': 0,
#          '#kunoriforceo': 0,
#          '#l4l': 0,
#          '#ladyposse': 0,
#          '#lafayette': 0,
#          '#latepost': 0,
#          '#latinhouse': 0,
#          '#lazy': 0,
#          '#lazyweekend': 0,
#          '#lbloggers': 0,
#          '#leeds': 0,
#          '#legsupthewall': 0,
#          '#leica': 0,
#          '#leicaq': 0,
#          '#lelomustfall': 0,
#          '#leo': 0,
#          '#lesbian': 0,
#          '#letitgrow': 0,
#          '#letsfootball': 0,
#          '#letsgetmessy': 0,
#          '#letsprocrastinate': 0,
#          '#lfccw': 0,
#          '#lgbt': 0,
#          '#lifestyle': 0,
#          '#like4like': 0,
#          '#likeforfollow': 0,
#          '#likeforlike': 0,
#          '#liveonstreamate': 0,
#          '#livesex': 0,
#          '#lizaminnelli': 0,
#          '#llaollao': 0,
#          '#lnhs': 0,
#          '#localgaragederby': 0,
#          '#lol': 0,
#          '#london': 0,
#          '#londondairy': 0,
#          '#londoutrading': 0,
#          '#lookfortheo': 0,
#          '#looking4aspot': 0,
#          '#louisiana': 0,
#          '#louisianashooting': 0,
#          '#love': 0,
#          '#loveforfood': 0,
#          '#lovenafianna': 0,
#          '#loveofmylife': 0,
#          '#lovesummertime': 0,
#          '#loveu': 0,
#          '#loveyeah': 0,
#          '#loveyoutilltheendcarter': 0,
#          '#lumia': 0,
#          '#lungomare': 0,
#          '#lux': 0,
#          '#luxurytravel': 0,
#          '#m5m6junction': 0,
#          '#mad': 0,
#          '#madness': 0,
#          '#madonnafamily': 0,
#          '#madonnafans': 0,
#          '#madonnamademtv': 0,
#          '#magicalkenya': 0,
#          '#magicalmysterytour': 0,
#          '#magictrik': 0,
#          '#magnificent': 0,
#          '#makeup': 0,
#          '#marine': 0,
#          '#maritimenation': 0,
#          '#marketing': 0,
#          '#marvel': 0,
#          '#masaantoday': 0,
#          '#mastership': 0,
#          '#matteroftheheart': 0,
#          '#maxfreshmove': 0,
#          '#mca': 0,
#          '#mcfc': 0,
#          '#mclaren': 0,
#          '#me': 0,
#          '#meanies': 0,
#          '#melbourneburgers': 0,
#          '#melbournetrip2015': 0,
#          '#mememe': 0,
#          '#memotohaters': 0,
#          '#messengerforaday': 0,
#          "#microsoft's": 0,
#          '#mididresses': 0,
#          '#midlands': 0,
#          '#milf': 0,
#          '#minecraft': 0,
#          '#misundersranding': 0,
#          '#mmsmalubhangsakit': 0,
#          '#mobilegame': 0,
#          '#mobilegames': 0,
#          '#model': 0,
#          '#models': 0,
#          '#morefuninthephilippines': 0,
#          '#morning': 0,
#          '#mornings': 0,
#          '#morocco': 0,
#          '#motn': 0,
#          '#moviemarathon': 0,
#          '#movingonup': 0,
#          '#mpoints': 0,
#          '#msnbc': 0,
#          '#mtn8': 0,
#          '#mtvhottest': 0,
#          '#muertosatfringe': 0,
#          '#mufc': 0,
#          '#mugshot': 0,
#          '#music': 0,
#          '#musicbiz': 0,
#          '#musicology2015': 0,
#          '#muslims': 0,
#          '#mustread': 0,
#          '#mybrainneedstoshutoff': 0,
#          '#mymonsoonstory': 0,
#          '#mypapamypride': 0,
#          '#mysummer': 0,
#          '#n04js': 0,
#          '#nailedit': 0,
#          '#nakamaforever': 0,
#          '#naked': 0,
#          '#natgeo': 0,
#          '#nathanielhinanakit': 0,
#          '#navy': 0,
#          '#nba': 0,
#          '#nbheroes': 0,
#          '#ncaaseason91': 0,
#          '#needicecreamnow': 0,
#          '#newbethvideo': 0,
#          '#newblogpost': 0,
#          '#newdress': 0,
#          '#newmusic': 0,
#          '#newsdistribution': 0,
#          '#newwine15': 0,
#          '#ngarepfollbackdarinabilahjkt48': 0,
#          '#nike': 0,
#          '#nikeindonesia': 0,
#          '#nikeoriginal': 0,
#          '#niteflirt': 0,
#          '#nknkkpagpapakumbaba': 0,
#          '#nomnomnom': 0,
#          '#nomoney': 0,
#          '#nonscripted': 0,
#          '#nostalgia': 0,
#          '#notanapology': 0,
#          '#notcool': 0,
#          '#notgonnabeactivefor2weeksdontmissittoomuch': 0,
#          '#nothavingit': 0,
#          '#nowplaying': 0,
#          '#nrltigersroosters': 0,
#          '#nsfw': 0,
#          '#nsn_supplements': 0,
#          '#nudes': 0,
#          '#nuka': 0,
#          '#obamainkenya': 0,
#          '#ocean': 0,
#          '#omegle': 0,
#          '#onair': 0,
#          '#onemochaonelove': 0,
#          '#ontheroadagain2015': 0,
#          '#open': 0,
#          '#openfollow': 0,
#          '#oralsex': 0,
#          '#orcalove': 0,
#          '#organic': 0,
#          '#orgasm': 0,
#          '#otwolgrandtrailer': 0,
#          '#ouch': 0,
#          '#ourdaughtersourpride': 0,
#          '#ourdisneyinfinity': 0,
#          '#outie': 0,
#          '#oxford': 0,
#          '#pabebegirls': 0,
#          '#pain': 0,
#          '#painting': 0,
#          '#pandora': 0,
#          '#parents': 0,
#          '#parijat': 0,
#          '#paris': 0,
#          '#party': 0,
#          '#patent': 0,
#          '#pbb737bigatingconcert': 0,
#          '#pbb737gold': 0,
#          '#pbevent': 0,
#          '#pbloggers': 0,
#          '#pcgaming': 0,
#          '#pcupgrade': 0,
#          '#pdapaghimok': 0,
#          '#peace': 0,
#          '#peachyloans': 0,
#          '#penacova': 0,
#          '#penyfan': 0,
#          '#perfection': 0,
#          '#pesaro': 0,
#          '#petjam': 0,
#          '#pglcsgo': 0,
#          '#phandroid': 0,
#          '#philosophical': 0,
#          '#phone': 0,
#          '#phonesex': 0,
#          '#photo': 0,
#          '#photography': 0,
#          '#photooftheday': 0,
#          '#pierojogger': 0,
#          '#pijjabłka': 0,
#          '#pistols': 0,
#          '#pitchwars': 0,
#          '#pixel_dailies': 0,
#          '#pixelart': 0,
#          '#pk': 0,
#          '#pkwalasawaal': 0,
#          '#planetbollywoodnews': 0,
#          '#poldi': 0,
#          '#poorkid': 0,
#          '#porn': 0,
#          '#porno': 0,
#          '#porschesupercup': 0,
#          '#portugal2015': 0,
#          '#postive': 0,
#          '#potassium': 0,
#          '#povertyyouareevil': 0,
#          '#prada': 0,
#          '#premiostumundo': 0,
#          '#pressrelease': 0,
#          '#pretty': 0,
#          '#pri': 0,
#          '#pricelessantique': 0,
#          '#prokabaddi': 0,
#          '#prosecco': 0,
#          '#proudtobeme': 0,
#          '#prrequest': 0,
#          '#psygustokita': 0,
#          '#pti': 0,
#          '#pump': 0,
#          '#punjabiswillgetit': 0,
#          '#pussy': 0,
#          '#putovanja': 0,
#          '#qatarday': 0,
#          '#quacketyquack': 0,
#          '#quadbiking': 0,
#          '#quest': 0,
#          '#quitkarwaoyaaro': 0,
#          '#quiz': 0,
#          '#quote': 0,
#          '#rain': 0,
#          '#rajnigandha': 0,
#          '#randomreboot': 0,
#          '#randomrestart': 0,
#          '#ratbaglater': 0,
#          '#reading': 0,
#          '#readystock_hijabmart': 0,
#          '#realoshi': 0,
#          '#realreviews': 0,
#          '#recipes': 0,
#          '#rehydrate': 0,
#          '#repost': 0,
#          '#residents': 0,
#          '#respectlost': 0,
#          '#retail': 0,
#          '#retweet': 0,
#          '#revamp': 0,
#          '#riprishikeshwari': 0,
#          '#ripsandrabland': 0,
#          '#ripstegi': 0,
#          '#riptito': 0,
#          '#rma': 0,
#          '#rmtour2015': 0,
#          '#robbenisland': 0,
#          '#rock': 0,
#          '#rogerwatch': 0,
#          '#rohingya': 0,
#          '#romance': 0,
#          '#roommateexperience': 0,
#          '#rp': 0,
#          '#rudramadevi': 0,
#          '#rxthedailysurveyvotes': 0,
#          '#sabadodeganarseguidores': 0,
#          '#sad': 0,
#          '#sadlyf': 0,
#          '#safari': 0,
#          '#sandrabland': 0,
#          '#sandroforceo': 0,
#          '#savetherohingya': 0,
#          '#sayhername': 0,
#          '#schoolsoutforsummer': 0,
#          '#scififan': 0,
#          '#scotlandismassive': 0,
#          '#se100leaders': 0,
#          '#sea': 0,
#          '#sect': 0,
#          '#seduce': 0,
#          '#selamathariraya': 0,
#          '#selfie': 0,
#          '#selfies': 0,
#          '#selfshot': 0,
#          '#sellyourcarin5words': 0,
#          '#sensiesha': 0,
#          '#servicewithasmile': 0,
#          '#sex': 0,
#          '#sexcam': 0,
#          '#sexcams': 0,
#          '#sexchat': 0,
#          '#sexdate': 0,
#          '#sexi': 0,
#          '#sexo': 0,
#          '#sextaatequemfimseguesdvcomvalentino': 0,
#          '#sexting': 0,
#          '#sexual': 0,
#          '#sexy': 0,
#          '#sexygirlbypreciouslemmy': 0,
#          '#sexysasunday': 0,
#          '#sexysaturday': 0,
#          '#sfs': 0,
#          '#sfvbeta': 0,
#          '#shalwarkameez': 0,
#          '#shane': 0,
#          '#sharethelove': 0,
#          '#shareyoursummer': 0,
#          '#sharing': 0,
#          '#sheskindahot': 0,
#          '#shipping': 0,
#          '#shithouse': 0,
#          '#showbox': 0,
#          '#showinginterest': 0,
#          '#sidemen': 0,
#          '#singapore': 0,
#          '#skoy': 0,
#          '#sky': 0,
#          '#skype': 0,
#          '#sleepdeprived': 0,
#          '#sleepingwithsirens': 0,
#          '#sleeptight': 0,
#          '#slovenia': 0,
#          '#smashingbook5': 0,
#          '#sme': 0,
#          '#smile': 0,
#          '#snapchat': 0,
#          '#snapchatme': 0,
#          '#snapdirty': 0,
#          '#snapme': 0,
#          '#sniff': 0,
#          '#soamazing': 0,
#          '#sobtian': 0,
#          '#socent': 0,
#          '#socialrewards': 0,
#          '#sociamedia': 0,
#          '#sohappyrightnow': 0,
#          '#song': 0,
#          '#soon': 0,
#          '#soproud': 0,
#          '#sorry': 0,
#          '#sosweet': 0,
#          '#sotired': 0,
#          '#sotw': 0,
#          '#soul': 0,
#          '#soulful': 0,
#          '#soulsurvivor15': 0,
#          '#spinorbinmusicxcodysimpson': 0,
#          '#spn11': 0,
#          '#spnfamily': 0,
#          '#srbija': 0,
#          '#stafford': 0,
#          '#standrews': 0,
#          '#standwdik': 0,
#          '#starsquad': 0,
#          '#startup': 0,
#          '#startupph': 0,
#          '#starwars': 0,
#          '#stay_blessed': 0,
#          '#stayfresh': 0,
#          '#stexpert': 0,
#          '#store': 0,
#          '#sugarrush': 0,
#          '#summer': 0,
#          '#summerismissing': 0,
#          '#summertime': 0,
#          '#sunflowers': 0,
#          '#sunjam': 0,
#          '#sunnyday': 0,
#          '#sunshine': 0,
#          '#superhappy': 0,
#          '#superheroes': 0,
#          '#superjunior': 0,
#          '#supersmash': 0,
#          '#support': 0,
#          '#sweetbj': 0,
#          '#sws': 0,
#          '#syria': 0,
#          '#t20': 0,
#          '#t20blast': 0,
#          '#taeny': 0,
#          '#tagsforlikes': 0,
#          '#tagsforlikesapp': 0,
#          '#takesonetoknowone': 0,
#          '#talk': 0,
#          '#taunton': 0,
#          '#taxikitchen': 0,
#          '#tb': 0,
#          '#tbs': 0,
#          '#tbt': 0,
#          '#tcot': 0,
#          '#tdf2015': 0,
#          '#tdif': 0,
#          '#teamadmicro': 0,
#          '#teamcannibal': 0,
#          '#teamfollowback': 0,
#          '#teamjanuaryclaims100': 0,
#          '#teamnatural': 0,
#          '#teampositive': 0,
#          '#teamred': 0,
#          '#teamspacewhalingisthebest': 0,
#          '#teamzipal': 0,
#          '#tech': 0,
#          '#teen': 0,
#          '#teenchoice': 0,
#          '#teens': 0,
#          '#telecoms': 0,
#          '#tellanoldjokeday': 0,
#          '#tengkuaaronshah': 0,
#          '#tennunb': 0,
#          '#texture': 0,
#          '#tgif': 0,
#          '#tgp1': 0,
#          '#thankyou': 0,
#          '#thankyou1dfor': 0,
#          '#thatscold': 0,
#          ...})

# %%
uni_unique_counts = pd.Series(unigram_counts_per_tweet)

# %%
all_tweets = pd.Series(all_tweets)

# %%
#form the dataframe 
tweet_df = pd.concat([all_tweets, uni_unique_counts], axis=1)

# %%
tweet_df
# Out:
#                                                       0  \
# 0     [#followfriday, @france_inte, @pkuchly57, @mil...
# 1     [@lamb2ja, hey, james, !, how, odd, :/, please...
# 2     [@despiteofficial, we, had, a, listen, last, n...
# 3                              [@97sides, congrats, :)]
# 4     [yeaaaah, yippppy, !, !, !, my, accnt, verifie...
# ...                                                 ...
# 9995      [i, wanna, change, my, avi, but, usanele, :(]
# 9996                  [my, puppy, broke, her, foot, :(]
# 9997  [where's, all, the, jaebum, baby, pictures, :(...
# 9998  [but, but, mr, ahmad, maslan, cooks, too, :(, ...
# 9999  [@eawoman, as, a, hull, supporter, i, am, expe...
#
#                                                       1
# 0     {'!': 0, '"': 0, '#': 0, '##bbmme': 0, '##sega...
# 1     {'!': 0, '"': 0, '#': 0, '##bbmme': 0, '##sega...
# 2     {'!': 0, '"': 0, '#': 0, '##bbmme': 0, '##sega...
# 3     {'!': 0, '"': 0, '#': 0, '##bbmme': 0, '##sega...
# 4     {'!': 0, '"': 0, '#': 0, '##bbmme': 0, '##sega...
# ...                                                 ...
# 9995  {'!': 0, '"': 0, '#': 0, '##bbmme': 0, '##sega...
# 9996  {'!': 0, '"': 0, '#': 0, '##bbmme': 0, '##sega...
# 9997  {'!': 0, '"': 0, '#': 0, '##bbmme': 0, '##sega...
# 9998  {'!': 0, '"': 0, '#': 0, '##bbmme': 0, '##sega...
# 9999  {'!': 0, '"': 0, '#': 0, '##bbmme': 0, '##sega...
#
# [10000 rows x 2 columns]

# %%
word_counts
# Out:
# Counter({'!': 2675,
#          '"': 479,
#          '#': 22,
#          '##bbmme': 2,
#          '##segalakatakata': 1,
#          '#100reasonstovisitmombasa': 1,
#          '#1948': 1,
#          '#1tbps4': 1,
#          '#2fm': 1,
#          '#39': 1,
#          '#4thstreetmusic': 1,
#          '#50notifications': 1,
#          '#5minute': 1,
#          '#actuallythough': 1,
#          '#addme': 2,
#          '#addmeonbbm': 1,
#          '#addmeonsnapchat': 3,
#          '#admin_myung': 1,
#          '#aflblueshawks': 2,
#          '#agnezmo': 1,
#          '#airfields': 1,
#          '#airforce': 1,
#          '#airport': 1,
#          '#akshaymostlovedsuperstarever': 1,
#          '#akua': 2,
#          '#al_master_band': 1,
#          '#alberta': 1,
#          '#aldub': 3,
#          '#alevel': 1,
#          '#alienthought': 1,
#          '#allgoodthingske': 1,
#          '#aluminiumfree': 1,
#          '#alwayskeepfighting': 1,
#          '#am': 2,
#          '#amateur': 5,
#          '#amazon': 4,
#          '#aminormalyet': 1,
#          '#amnotness': 1,
#          '#android': 2,
#          '#angel': 1,
#          '#ans2win': 1,
#          '#anushka': 1,
#          '#anywayhedidanicejob': 1,
#          '#aragalang08': 1,
#          '#art': 3,
#          '#ashramcalling': 1,
#          '#askaman': 1,
#          '#askfinnick': 1,
#          '#askurban': 1,
#          '#athabasca': 1,
#          '#atk': 2,
#          '#ausfailia': 1,
#          '#autofollow': 3,
#          '#auvssscr': 1,
#          '#awami': 1,
#          '#babe': 2,
#          '#backflip': 1,
#          '#bad': 1,
#          '#bad4thwin': 4,
#          '#bae': 2,
#          '#bajrangibhaijaanhighestweek1': 7,
#          '#bajrangibhaijaanstorm': 1,
#          '#band': 2,
#          '#banter': 1,
#          '#barkada': 1,
#          '#barsostay': 1,
#          '#basketball': 1,
#          '#batalladelosgallos': 2,
#          '#batb': 1,
#          '#battlefield': 1,
#          '#bb17': 1,
#          '#bblf': 1,
#          '#bbloggers': 1,
#          '#bbmadeinmanila': 1,
#          '#bbmme': 1,
#          '#bbmpin': 2,
#          '#bboying': 1,
#          '#bc': 1,
#          '#bcyc': 1,
#          '#be': 1,
#          '#beauty': 1,
#          '#bebravetoday': 1,
#          '#beliebers': 1,
#          '#bellevue': 1,
#          '#bellybutton': 4,
#          '#bellybuttons': 1,
#          '#beme': 1,
#          '#bemeapp': 1,
#          '#bemecode': 1,
#          '#beograd': 1,
#          '#beonknockknock': 1,
#          '#besteverdoctorwhoepisode': 1,
#          '#bestfriend': 1,
#          '#bestoftheday': 4,
#          '#bestweekend': 1,
#          '#betting': 1,
#          '#bff': 1,
#          '#bffs': 1,
#          '#bindingofissac': 1,
#          '#birmingham': 1,
#          '#birthday': 1,
#          '#birthdaygirl': 1,
#          '#birthdaymoneyforjesusjuice': 1,
#          '#birthdaymonth': 1,
#          '#birthdaypresent': 1,
#          '#blackcountryfair': 1,
#          '#blacklivesmatter': 1,
#          '#blamehoney': 1,
#          '#blameshoghicp': 1,
#          '#bleedgreen': 1,
#          '#blockjam': 1,
#          '#blog': 1,
#          '#bloggersrequired': 1,
#          '#bloggerswanted': 1,
#          '#blonde': 2,
#          '#bloodline': 1,
#          '#blowjob': 1,
#          '#bluejays': 1,
#          '#bluesidemenxix': 1,
#          '#bmc': 1,
#          '#bollywood': 1,
#          '#bombing': 1,
#          '#bookreview': 1,
#          '#boom': 1,
#          '#booty': 2,
#          '#borderlands': 1,
#          '#bored': 3,
#          '#bot': 2,
#          '#bowwowchicawowwow': 1,
#          '#boxroomcrafts': 1,
#          '#brainchild': 1,
#          '#braindots': 11,
#          '#branding': 1,
#          '#brasileirao': 2,
#          '#breaktym': 1,
#          '#breconbeacons': 1,
#          '#brewproject': 1,
#          '#brijresidency': 1,
#          '#brilliant': 1,
#          '#bringmethehorizon': 1,
#          '#bristolart': 1,
#          '#brum': 1,
#          '#buckinghampalace': 1,
#          '#budapestgp': 1,
#          '#buddy': 1,
#          '#bugbounty': 1,
#          '#bulldog': 1,
#          '#bunso': 1,
#          '#burger': 2,
#          '#burgers': 1,
#          '#burnley': 1,
#          '#buynotanapologyonitunes': 1,
#          '#caesarspalace': 1,
#          '#cajunchicken': 1,
#          '#cakehamper': 1,
#          '#calibraksaep': 2,
#          '#calibraskaep': 3,
#          '#callinganimalabusehotlineasap': 1,
#          '#cam4': 1,
#          '#cambridge': 1,
#          '#camsex': 5,
#          '#canvas': 1,
#          '#cardgame': 1,
#          '#cc': 5,
#          '#centrifugal': 1,
#          '#ceo1month': 11,
#          '#chaloniklo': 2,
#          '#chat': 7,
#          '#cheatday': 1,
#          '#checking': 1,
#          '#cheesydelights': 1,
#          '#cheltenham': 1,
#          '#cheshire': 1,
#          '#chocolate': 1,
#          '#choiceinternationalartist': 14,
#          '#cimbom': 1,
#          '#circuscircus': 1,
#          '#cjradacomateada': 2,
#          '#clapham': 1,
#          '#classicassures': 1,
#          '#clientvisit': 1,
#          '#climatechange': 5,
#          '#cnn': 1,
#          '#cocktails': 1,
#          '#coffee': 2,
#          '#colorpencils': 1,
#          '#colors': 1,
#          '#commercial': 1,
#          '#commodore64': 1,
#          '#community': 1,
#          '#concert': 2,
#          '#contestkiduniya': 2,
#          '#coolingtowers': 1,
#          '#cosplay': 1,
#          '#cosplayprogress': 1,
#          '#costacc': 1,
#          '#countrymusic': 5,
#          '#countthecost': 1,
#          '#couple': 1,
#          '#couscous': 1,
#          '#cp': 1,
#          '#cplt20': 1,
#          '#cray': 1,
#          '#credits': 1,
#          '#cretaperfect4me': 2,
#          '#cretaperfectsuv': 2,
#          '#crowdfunding': 1,
#          '#crush': 1,
#          '#csrracing': 1,
#          '#cumbria': 1,
#          '#cumshot': 1,
#          '#cute': 4,
#          '#cyclerevolution': 1,
#          '#cycling': 1,
#          '#cyprus': 1,
#          '#dancetastic': 1,
#          '#danzell': 1,
#          '#day2': 1,
#          '#dayofarch': 1,
#          '#dealsuthaonotebachao': 1,
#          '#dearslim': 2,
#          '#deathbybaconsmell': 1,
#          '#deathcure': 1,
#          '#deathofgrass': 1,
#          '#decorating': 1,
#          '#dedicatedfan': 1,
#          '#delivery': 1,
#          '#dessert': 1,
#          '#determination': 1,
#          '#development': 1,
#          '#digitalexeter': 1,
#          '#digitalmarketing': 1,
#          '#dinner': 1,
#          '#dirtykik': 2,
#          '#disappointed': 1,
#          '#discrimination': 2,
#          '#dishoom': 2,
#          '#disneyinfinity': 1,
#          '#divinediscontent': 1,
#          '#diyflowers': 1,
#          '#djderek': 1,
#          '#djset': 1,
#          '#djstruthmate': 1,
#          '#dmme': 3,
#          '#docopenhagen': 1,
#          '#domesticviolence': 1,
#          '#dominion': 2,
#          '#doodle': 1,
#          '#dota2': 2,
#          '#dreamteam': 1,
#          '#drinkitallup': 1,
#          '#dtangle': 1,
#          '#dublin': 1,
#          '#dukefreebiefriday': 1,
#          '#eatmeat': 1,
#          '#ebony': 2,
#          '#eczema': 1,
#          '#edm': 2,
#          '#educampakl': 1,
#          '#eh': 1,
#          '#eid': 1,
#          '#eidwithgrofers': 1,
#          '#ejayster': 1,
#          '#eksperimencinta': 1,
#          '#elephantgod': 1,
#          '#elfindelmundo': 3,
#          '#elgin': 1,
#          '#elizabetholsen': 1,
#          '#emojasp_here': 1,
#          '#england': 1,
#          '#enjoy': 1,
#          '#entrepreneur': 1,
#          '#equalityact': 1,
#          '#escape': 1,
#          '#essay': 1,
#          '#estatic': 1,
#          '#etid': 1,
#          '#etsy': 1,
#          '#excited': 1,
#          '#exo': 1,
#          '#expediajobs': 1,
#          '#explorealberta': 1,
#          '#extremesports': 1,
#          '#fabfriday': 2,
#          '#facetime': 4,
#          '#fahrinahmad': 1,
#          '#fail2ban': 1,
#          '#failsatlife': 1,
#          '#fallout4': 1,
#          '#family': 3,
#          '#familyhome': 1,
#          '#fanart': 1,
#          '#fantastic': 1,
#          '#farm': 1,
#          '#fashionfriday': 1,
#          '#favourites': 1,
#          '#fb': 1,
#          '#feelgoodfriday': 1,
#          '#feelinggood': 1,
#          '#feelslikeanidiot': 1,
#          '#feminism': 1,
#          '#fenestoscope': 1,
#          '#fever': 1,
#          '#ff': 46,
#          '#ffback': 2,
#          '#fightingmcirene': 1,
#          '#fightstickfriday': 1,
#          '#filbarbarian': 1,
#          '#finance': 1,
#          '#findavip': 1,
#          '#finddjderek': 1,
#          '#findyourfit': 1,
#          '#fingerscrossed': 1,
#          '#finland': 1,
#          '#first50europe': 1,
#          '#fish': 1,
#          '#fitfa': 1,
#          '#fixedgearfrenzy': 1,
#          '#flipkartfashionfriday': 17,
#          '#flippin': 1,
#          '#flockstars': 1,
#          '#flowers': 1,
#          '#fls': 1,
#          '#flyhigh': 1,
#          '#fm15': 1,
#          '#fmfamily': 1,
#          '#fnaf4': 1,
#          '#foampit': 1,
#          '#foiegras': 2,
#          '#follow': 4,
#          '#followback': 3,
#          '#followfriday': 25,
#          '#followmeaaron': 1,
#          '#food': 5,
#          '#foodforthought': 1,
#          '#foodiefridays': 1,
#          '#foreveralone': 2,
#          '#forklift': 1,
#          '#fortune500': 1,
#          '#free': 4,
#          '#freebiefriday': 5,
#          '#freedom': 1,
#          '#french': 4,
#          '#frequentflyer': 1,
#          '#fresherstofinals': 1,
#          '#friday': 12,
#          "#friday's": 1,
#          '#fridaydownpour': 1,
#          '#fridayfauxpas': 1,
#          '#fridayfeeling': 6,
#          '#fridayfreebie': 1,
#          '#fridayfun': 1,
#          '#fridayfunday': 1,
#          '#fridaylouge': 1,
#          '#fridays': 1,
#          '#friends': 2,
#          '#friskyfiday': 1,
#          '#friskyfriday': 1,
#          '#friyay': 1,
#          '#frnds': 1,
#          '#frustration': 1,
#          '#fuck': 3,
#          '#fun': 1,
#          '#funny': 1,
#          '#futurereleases': 1,
#          '#fxhelp': 1,
#          '#fyeah': 1,
#          '#gamedesign': 1,
#          '#gamedev': 2,
#          '#gamer': 1,
#          '#gamers': 1,
#          '#ganesha': 1,
#          '#gay': 5,
#          '#geek': 1,
#          '#ges2015kenya': 1,
#          '#geskenya': 1,
#          '#getthescoop': 1,
#          '#getwellsoonamber': 1,
#          '#giachietittiwedding': 1,
#          '#girl': 1,
#          '#girlfriendsmya': 1,
#          '#girls': 2,
#          '#giveaway': 2,
#          '#givecodpieceachance': 1,
#          '#giveitup': 1,
#          '#glacier': 1,
#          '#goa': 1,
#          '#gobigorgohome': 1,
#          '#godonna': 1,
#          '#gohf': 3,
#          '#gohf2015': 1,
#          '#goldbugs': 1,
#          '#goldcoast': 1,
#          '#goodafternoon': 1,
#          '#goodmorning': 5,
#          '#goodmusic': 4,
#          '#goodnight': 1,
#          '#goodwynsgoodies': 1,
#          '#goodyear': 1,
#          '#goofingaround': 1,
#          '#gorgeous': 1,
#          '#got7': 3,
#          '#gotham': 1,
#          '#gottolovebanks': 1,
#          '#gp': 1,
#          '#graphicdesign': 1,
#          '#greatkenya': 1,
#          '#greece': 1,
#          '#greekcrisis': 1,
#          '#greeks': 1,
#          '#greysonchance': 1,
#          '#gross': 1,
#          '#growinguppoor': 1,
#          '#gto': 1,
#          '#gunashekar': 1,
#          '#guncontrol': 1,
#          '#gutted': 1,
#          '#gym': 1,
#          '#h_my_king': 1,
#          '#haaretz': 1,
#          '#hagergang': 1,
#          '#haileyhelps': 1,
#          '#hair': 1,
#          '#hale': 1,
#          '#halesowen': 1,
#          '#hannibal': 5,
#          '#happy': 6,
#          '#happyalien': 1,
#          '#happybirthdayemilybett': 1,
#          '#happycustomers': 1,
#          '#happyfriday': 6,
#          '#happyfriedday': 1,
#          '#happyweekend': 1,
#          '#hashtags': 1,
#          '#haveagoodday': 1,
#          '#hbdme': 1,
#          '#healthylifestyle': 1,
#          '#hello': 1,
#          '#helsinki': 1,
#          '#henessydiaries': 1,
#          '#heroes': 1,
#          '#hibye': 1,
#          '#highschooldays': 1,
#          '#hindugod': 1,
#          '#hinduism': 1,
#          '#hiring': 1,
#          '#holiday': 3,
#          '#hopetowin': 1,
#          '#horny': 2,
#          '#hornykik': 19,
#          '#horseracing': 1,
#          '#horseracingtips': 1,
#          '#horses': 1,
#          '#hot': 5,
#          '#hotairballoon': 1,
#          '#hotel': 2,
#          '#hotels': 3,
#          '#hotfmnoaidilforariana': 2,
#          '#hotgirls': 2,
#          '#hotmusicdelocos': 3,
#          '#hotnsexy': 1,
#          '#hotscratch': 1,
#          '#hotspotwithdanris': 1,
#          '#hottie': 3,
#          '#housemusic': 3,
#          '#hr': 1,
#          '#hrdstellobama': 1,
#          '#hugs': 1,
#          '#hulkhogan': 1,
#          '#hushedcallwithfraydoe': 1,
#          '#hushedpinwithsammy': 2,
#          '#huskies': 1,
#          '#hype': 1,
#          '#hypixel': 1,
#          '#hyungbot': 1,
#          '#iamamonster': 1,
#          '#iamca': 1,
#          '#icecream': 4,
#          '#icecreammaster': 1,
#          '#ifimeetanalien': 1,
#          '#igersoftheday': 1,
#          '#ihatesomepeople': 1,
#          '#ikprideofpak': 1,
#          '#ilikeit': 1,
#          '#iloveyou': 2,
#          '#imintoher': 1,
#          '#imveryverysorry': 1,
#          '#incall': 1,
#          '#incredibleindia': 1,
#          '#indian': 1,
#          '#indiedev': 1,
#          '#indiemusic': 15,
#          '#indonesia': 3,
#          '#ineedfeminismbecause': 1,
#          '#innie': 4,
#          '#innovation': 1,
#          '#inspire': 1,
#          '#inspy': 1,
#          '#instagood': 2,
#          '#instagram': 2,
#          '#instamood': 3,
#          '#intel': 1,
#          '#interracial': 4,
#          '#ios8': 2,
#          '#iqrar': 1,
#          '#iran': 1,
#          '#irandeal': 1,
#          '#iraq': 1,
#          '#isibaya': 1,
#          '#isis': 1,
#          '#isolated': 1,
#          '#israel': 1,
#          '#itsamarvelthing': 1,
#          '#itter': 1,
#          '#iwishiknewbetter': 1,
#          '#jabongatpumaurbanstampede': 6,
#          '#jaredpadalecki': 1,
#          '#jasper': 1,
#          '#jaspernationalpark': 1,
#          '#jcreport': 1,
#          '#jealous': 1,
#          '#jebbush': 1,
#          '#jedzjabłka': 1,
#          '#jeep': 3,
#          '#jensenackles': 1,
#          '#jeremy4leader': 1,
#          '#jets': 1,
#          '#jezwecan': 1,
#          '#jgh': 1,
#          '#jilla': 1,
#          '#jiva': 1,
#          '#job': 2,
#          '#jobs': 1,
#          '#johnforceo': 1,
#          '#johnyherbert': 1,
#          '#jonathancreek': 1,
#          '#jordan': 1,
#          '#journeyps4': 2,
#          '#journorequest': 1,
#          '#judo': 1,
#          '#july24th': 1,
#          '#jumma_mubarik': 1,
#          '#jummamubarak': 1,
#          '#jummaprayer': 1,
#          '#jumpgiants': 1,
#          '#justgotkanekified': 1,
#          '#justiceforsandrabland': 2,
#          '#kadhafi': 2,
#          '#kapatidkongpogi': 1,
#          '#karani': 1,
#          '#karibumombasa': 1,
#          '#kca': 1,
#          '#keepitlocal': 2,
#          '#keepsafealways': 1,
#          '#kfc': 1,
#          '#kfckitchentours': 2,
#          '#kianweareproud': 1,
#          '#kidschoiceawards2015': 1,
#          '#kik': 47,
#          '#kikchat': 10,
#          '#kikgirl': 18,
#          '#kikhorny': 14,
#          '#kikkomansabor': 3,
#          '#kikme': 9,
#          '#kikmeboys': 16,
#          '#kikmeguys': 8,
#          '#kikmenow': 12,
#          '#kikmsn': 2,
#          '#kiksex': 8,
#          '#kiksexting': 11,
#          "#kinara's": 1,
#          '#kissme': 2,
#          '#kitkat': 1,
#          '#kizomba': 1,
#          '#ktksbye': 1,
#          '#ku': 1,
#          '#kunoriforceo': 8,
#          '#l4l': 3,
#          '#ladyposse': 1,
#          '#lafayette': 2,
#          '#latepost': 1,
#          '#latinhouse': 1,
#          '#lazy': 1,
#          '#lazyweekend': 1,
#          '#lbloggers': 1,
#          '#leeds': 2,
#          '#legsupthewall': 1,
#          '#leica': 1,
#          '#leicaq': 1,
#          '#lelomustfall': 1,
#          '#leo': 1,
#          '#lesbian': 4,
#          '#letitgrow': 1,
#          '#letsfootball': 2,
#          '#letsgetmessy': 1,
#          '#letsprocrastinate': 1,
#          '#lfccw': 1,
#          '#lgbt': 5,
#          '#lifestyle': 1,
#          '#like4like': 6,
#          '#likeforfollow': 4,
#          '#likeforlike': 7,
#          '#liveonstreamate': 1,
#          '#livesex': 1,
#          '#lizaminnelli': 1,
#          '#llaollao': 1,
#          '#lnhs': 1,
#          '#localgaragederby': 1,
#          '#lol': 1,
#          '#london': 1,
#          '#londondairy': 1,
#          '#londoutrading': 1,
#          '#lookfortheo': 1,
#          '#looking4aspot': 1,
#          '#louisiana': 2,
#          '#louisianashooting': 1,
#          '#love': 4,
#          '#loveforfood': 1,
#          '#lovenafianna': 1,
#          '#loveofmylife': 2,
#          '#lovesummertime': 1,
#          '#loveu': 1,
#          '#loveyeah': 1,
#          '#loveyoutilltheendcarter': 1,
#          '#lumia': 1,
#          '#lungomare': 1,
#          '#lux': 1,
#          '#luxurytravel': 1,
#          '#m5m6junction': 1,
#          '#mad': 1,
#          '#madness': 1,
#          '#madonnafamily': 1,
#          '#madonnafans': 1,
#          '#madonnamademtv': 1,
#          '#magicalkenya': 1,
#          '#magicalmysterytour': 1,
#          '#magictrik': 2,
#          '#magnificent': 1,
#          '#makeup': 5,
#          '#marine': 2,
#          '#maritimenation': 1,
#          '#marketing': 1,
#          '#marvel': 1,
#          '#masaantoday': 6,
#          '#mastership': 1,
#          '#matteroftheheart': 1,
#          '#maxfreshmove': 2,
#          '#mca': 1,
#          '#mcfc': 1,
#          '#mclaren': 1,
#          '#me': 4,
#          '#meanies': 1,
#          '#melbourneburgers': 1,
#          '#melbournetrip2015': 1,
#          '#mememe': 2,
#          '#memotohaters': 1,
#          '#messengerforaday': 1,
#          "#microsoft's": 1,
#          '#mididresses': 1,
#          '#midlands': 1,
#          '#milf': 2,
#          '#minecraft': 3,
#          '#misundersranding': 1,
#          '#mmsmalubhangsakit': 1,
#          '#mobilegame': 1,
#          '#mobilegames': 1,
#          '#model': 5,
#          '#models': 3,
#          '#morefuninthephilippines': 1,
#          '#morning': 2,
#          '#mornings': 1,
#          '#morocco': 1,
#          '#motn': 1,
#          '#moviemarathon': 1,
#          '#movingonup': 1,
#          '#mpoints': 6,
#          '#msnbc': 1,
#          '#mtn8': 1,
#          '#mtvhottest': 1,
#          '#muertosatfringe': 1,
#          '#mufc': 1,
#          '#mugshot': 2,
#          '#music': 5,
#          '#musicbiz': 3,
#          '#musicology2015': 1,
#          '#muslims': 1,
#          '#mustread': 1,
#          '#mybrainneedstoshutoff': 1,
#          '#mymonsoonstory': 2,
#          '#mypapamypride': 2,
#          '#mysummer': 1,
#          '#n04js': 1,
#          '#nailedit': 1,
#          '#nakamaforever': 3,
#          '#naked': 1,
#          '#natgeo': 1,
#          '#nathanielhinanakit': 1,
#          '#navy': 1,
#          '#nba': 1,
#          '#nbheroes': 1,
#          '#ncaaseason91': 1,
#          '#needicecreamnow': 1,
#          '#newbethvideo': 1,
#          '#newblogpost': 1,
#          '#newdress': 1,
#          '#newmusic': 4,
#          '#newsdistribution': 1,
#          '#newwine15': 1,
#          '#ngarepfollbackdarinabilahjkt48': 1,
#          '#nike': 1,
#          '#nikeindonesia': 1,
#          '#nikeoriginal': 1,
#          '#niteflirt': 1,
#          '#nknkkpagpapakumbaba': 1,
#          '#nomnomnom': 1,
#          '#nomoney': 1,
#          '#nonscripted': 1,
#          '#nostalgia': 1,
#          '#notanapology': 6,
#          '#notcool': 1,
#          '#notgonnabeactivefor2weeksdontmissittoomuch': 1,
#          '#nothavingit': 1,
#          '#nowplaying': 1,
#          '#nrltigersroosters': 1,
#          '#nsfw': 2,
#          '#nsn_supplements': 1,
#          '#nudes': 4,
#          '#nuka': 1,
#          '#obamainkenya': 1,
#          '#ocean': 1,
#          '#omegle': 5,
#          '#onair': 1,
#          '#onemochaonelove': 1,
#          '#ontheroadagain2015': 1,
#          '#open': 1,
#          '#openfollow': 1,
#          '#oralsex': 5,
#          '#orcalove': 1,
#          '#organic': 1,
#          '#orgasm': 4,
#          '#otwolgrandtrailer': 7,
#          '#ouch': 1,
#          '#ourdaughtersourpride': 5,
#          '#ourdisneyinfinity': 1,
#          '#outie': 4,
#          '#oxford': 1,
#          '#pabebegirls': 1,
#          '#pain': 1,
#          '#painting': 1,
#          '#pandora': 1,
#          '#parents': 1,
#          '#parijat': 1,
#          '#paris': 1,
#          '#party': 1,
#          '#patent': 1,
#          '#pbb737bigatingconcert': 1,
#          '#pbb737gold': 3,
#          '#pbevent': 1,
#          '#pbloggers': 1,
#          '#pcgaming': 1,
#          '#pcupgrade': 1,
#          '#pdapaghimok': 1,
#          '#peace': 1,
#          '#peachyloans': 1,
#          '#penacova': 1,
#          '#penyfan': 1,
#          '#perfection': 1,
#          '#pesaro': 1,
#          '#petjam': 1,
#          '#pglcsgo': 1,
#          '#phandroid': 1,
#          '#philosophical': 1,
#          '#phone': 1,
#          '#phonesex': 3,
#          '#photo': 4,
#          '#photography': 1,
#          '#photooftheday': 6,
#          '#pierojogger': 1,
#          '#pijjabłka': 1,
#          '#pistols': 1,
#          '#pitchwars': 1,
#          '#pixel_dailies': 1,
#          '#pixelart': 1,
#          '#pk': 1,
#          '#pkwalasawaal': 2,
#          '#planetbollywoodnews': 1,
#          '#poldi': 1,
#          '#poorkid': 1,
#          '#porn': 2,
#          '#porno': 4,
#          '#porschesupercup': 1,
#          '#portugal2015': 1,
#          '#postive': 1,
#          '#potassium': 1,
#          '#povertyyouareevil': 1,
#          '#prada': 1,
#          '#premiostumundo': 4,
#          '#pressrelease': 1,
#          '#pretty': 1,
#          '#pri': 1,
#          '#pricelessantique': 1,
#          '#prokabaddi': 1,
#          '#prosecco': 1,
#          '#proudtobeme': 1,
#          '#prrequest': 1,
#          '#psygustokita': 6,
#          '#pti': 1,
#          '#pump': 1,
#          '#punjabiswillgetit': 1,
#          '#pussy': 5,
#          '#putovanja': 1,
#          '#qatarday': 1,
#          '#quacketyquack': 7,
#          '#quadbiking': 1,
#          '#quest': 1,
#          '#quitkarwaoyaaro': 1,
#          '#quiz': 1,
#          '#quote': 4,
#          '#rain': 4,
#          '#rajnigandha': 1,
#          '#randomreboot': 1,
#          '#randomrestart': 1,
#          '#ratbaglater': 1,
#          '#reading': 1,
#          '#readystock_hijabmart': 1,
#          '#realoshi': 1,
#          '#realreviews': 1,
#          '#recipes': 1,
#          '#rehydrate': 1,
#          '#repost': 2,
#          '#residents': 1,
#          '#respectlost': 1,
#          '#retail': 1,
#          '#retweet': 13,
#          '#revamp': 1,
#          '#riprishikeshwari': 1,
#          '#ripsandrabland': 1,
#          '#ripstegi': 1,
#          '#riptito': 1,
#          '#rma': 1,
#          '#rmtour2015': 1,
#          '#robbenisland': 1,
#          '#rock': 2,
#          '#rogerwatch': 1,
#          '#rohingya': 1,
#          '#romance': 1,
#          '#roommateexperience': 1,
#          '#rp': 1,
#          '#rudramadevi': 1,
#          '#rxthedailysurveyvotes': 1,
#          '#sabadodeganarseguidores': 3,
#          '#sad': 2,
#          '#sadlyf': 1,
#          '#safari': 1,
#          '#sandrabland': 6,
#          '#sandroforceo': 2,
#          '#savetherohingya': 1,
#          '#sayhername': 1,
#          '#schoolsoutforsummer': 1,
#          '#scififan': 1,
#          '#scotlandismassive': 1,
#          '#se100leaders': 1,
#          '#sea': 1,
#          '#sect': 1,
#          '#seduce': 2,
#          '#selamathariraya': 1,
#          '#selfie': 3,
#          '#selfies': 1,
#          '#selfshot': 2,
#          '#sellyourcarin5words': 2,
#          '#sensiesha': 1,
#          '#servicewithasmile': 1,
#          '#sex': 8,
#          '#sexcam': 1,
#          '#sexcams': 2,
#          '#sexchat': 1,
#          '#sexdate': 2,
#          '#sexi': 3,
#          '#sexo': 5,
#          '#sextaatequemfimseguesdvcomvalentino': 1,
#          '#sexting': 1,
#          '#sexual': 4,
#          '#sexy': 10,
#          '#sexygirlbypreciouslemmy': 3,
#          '#sexysasunday': 4,
#          '#sexysaturday': 1,
#          '#sfs': 2,
#          '#sfvbeta': 1,
#          '#shalwarkameez': 1,
#          '#shane': 1,
#          '#sharethelove': 2,
#          '#shareyoursummer': 1,
#          '#sharing': 1,
#          '#sheskindahot': 2,
#          '#shipping': 1,
#          '#shithouse': 1,
#          '#showbox': 1,
#          '#showinginterest': 1,
#          '#sidemen': 1,
#          '#singapore': 1,
#          '#skoy': 1,
#          '#sky': 1,
#          '#skype': 4,
#          '#sleepdeprived': 1,
#          '#sleepingwithsirens': 1,
#          '#sleeptight': 1,
#          '#slovenia': 1,
#          '#smashingbook5': 1,
#          '#sme': 1,
#          '#smile': 5,
#          '#snapchat': 55,
#          '#snapchatme': 6,
#          '#snapdirty': 1,
#          '#snapme': 6,
#          '#sniff': 1,
#          '#soamazing': 1,
#          '#sobtian': 1,
#          '#socent': 1,
#          '#socialrewards': 1,
#          '#sociamedia': 1,
#          '#sohappyrightnow': 1,
#          '#song': 1,
#          '#soon': 1,
#          '#soproud': 1,
#          '#sorry': 1,
#          '#sosweet': 1,
#          '#sotired': 1,
#          '#sotw': 1,
#          '#soul': 1,
#          '#soulful': 1,
#          '#soulsurvivor15': 1,
#          '#spinorbinmusicxcodysimpson': 1,
#          '#spn11': 1,
#          '#spnfamily': 1,
#          '#srbija': 1,
#          '#stafford': 1,
#          '#standrews': 1,
#          '#standwdik': 1,
#          '#starsquad': 4,
#          '#startup': 1,
#          '#startupph': 1,
#          '#starwars': 1,
#          '#stay_blessed': 1,
#          '#stayfresh': 1,
#          '#stexpert': 1,
#          '#store': 1,
#          '#sugarrush': 1,
#          '#summer': 9,
#          '#summerismissing': 1,
#          '#summertime': 1,
#          '#sunflowers': 1,
#          '#sunjam': 1,
#          '#sunnyday': 1,
#          '#sunshine': 2,
#          '#superhappy': 1,
#          '#superheroes': 1,
#          '#superjunior': 14,
#          '#supersmash': 1,
#          '#support': 1,
#          '#sweetbj': 1,
#          '#sws': 1,
#          '#syria': 1,
#          '#t20': 1,
#          '#t20blast': 2,
#          '#taeny': 1,
#          '#tagsforlikes': 9,
#          '#tagsforlikesapp': 2,
#          '#takesonetoknowone': 1,
#          '#talk': 5,
#          '#taunton': 1,
#          '#taxikitchen': 1,
#          '#tb': 1,
#          '#tbs': 1,
#          '#tbt': 2,
#          '#tcot': 9,
#          '#tdf2015': 1,
#          '#tdif': 1,
#          '#teamadmicro': 1,
#          '#teamcannibal': 1,
#          '#teamfollowback': 4,
#          '#teamjanuaryclaims100': 1,
#          '#teamnatural': 1,
#          '#teampositive': 1,
#          '#teamred': 1,
#          '#teamspacewhalingisthebest': 1,
#          '#teamzipal': 1,
#          '#tech': 1,
#          '#teen': 2,
#          '#teenchoice': 15,
#          '#teens': 5,
#          '#telecoms': 2,
#          '#tellanoldjokeday': 1,
#          '#tengkuaaronshah': 1,
#          '#tennunb': 1,
#          '#texture': 1,
#          '#tgif': 8,
#          '#tgp1': 1,
#          '#thankyou': 1,
#          '#thankyou1dfor': 1,
#          '#thatscold': 1,
#          ...})

# %%
unigrams_df
# Out:
#                      0  1
# 0        #followfriday  1
# 1         @france_inte  1
# 2           @pkuchly57  1
# 3       @milipol_paris  1
# 4                  for  1
# ...                ... ..
# 121042       expecting  1
# 121043      misserable  1
# 121044             few  1
# 121045           weeks  1
# 121046             :-(  1
#
# [121047 rows x 2 columns]

# %%
#calculating bigram features: 

#for pos tweets: 
bigram_pos_freq = [] 

for entry in positive_tweets_list:
    bigram_pos_zip = []
    text_for_pos_bigrams = nltk.ngrams(entry, 2)
    bigram_pos_zip.append(text_for_pos_bigrams)
    for zip_text in bigram_pos_zip: 
        bigram_frequency_distribution = nltk.FreqDist(zip_text)
        bigram_pos_freq.append(bigram_frequency_distribution)
bigram_pos = [tuple(entry.items()) for entry in bigram_pos_freq]


#for neg tweets: 
bigram_neg_freq = [] 

for entry in negative_tweets_list:
    bigram_neg_zip = []
    text_for_neg_bigrams = nltk.ngrams(entry, 2)
    bigram_neg_zip.append(text_for_neg_bigrams)
    for zip_text in bigram_neg_zip: 
        bigram_frequency_distribution = nltk.FreqDist(zip_text)
        bigram_neg_freq.append(bigram_frequency_distribution)
bigram_neg = [tuple(entry.items()) for entry in bigram_neg_freq]

# %% [markdown]
# ### Creating a Train/Test set Split
#
# Now that we're done calculating features and are ready to move onto making predictions, let's split up the examples into a training set and a test set, in order to avoid overfitting.
#
# Please split up the data with **80% in the training set** and the remaining **20% in the test set**.

# %%
# you can do a simple version (e.g., put the first 4000 
# positive examples into a training set)
# or you can also choose a random split.

# be sure to create labels too!
# Let's use 1 = pos, 0 = neg

# --- your code ---

# %% [markdown]
# ### Using the linguistic features to make predictions
#
# Now that you have calculated the linguistic features for each tweet, and you have divided your data into a training set and a test set, let's take stock of the main variables you should have. (Note: *num_features* may differ depending on the choices you made to calculate your features.)
#
# You should have:
#
# - a 8000 x *num_features* array that contains the features for the 8000 tweets in the training set
# - a 2000 x *num_features* array that contains the features for the 2000 tweets in the test set
# - a 8000 x 1 array that contains the labels (pos/neg) for the 8000 tweets in the training set
# - a 2000 x 1 array that contains the labels (pos/neg) for the 2000 tweets in the test set
#
# - an array that contains information on what each of the features mean (i.e., for the unigram/bigram features, this refers to the "vocabulary". You'll need this to interpret the results.)

# %% [markdown]
# If you've made it thus far, great, you're almost there! The remaining bit of work is to (i) train a model on the training set, (ii) evaluate the classification accuracy on the test set, and (iii) evaluate the features that are predictive of the label (and discuss).

# %%
# (i) Train a model on the training set

# please set up and train a logistic regression model on the training set.
# if your number of features is much larger than the training set size, you may wish to consider using regularization


# NOTE if you are using statsmodel, this may take a while to train.
# sklearn does it much faster. 

# --- your code ---

# %%
# (ii) Evaluate the classification accuracy on the test set

# Using your model, make label predictions on the test set (by using the model on the test features).
# compare them against the actual test set labels.
# what is the classification accuracy of this model?

# --- your code ---

# %%
# (iii) Evaluate the features that are predictive of the label (and discuss).

# Take a look at the features that are most predictive of the label. 
# For example, which unigrams or bigrams were most predictive?
# do these make sense?

# --- your code, and written text response ---
